# %% [markdown]
# # 1. Introduction to OOP
#
# In programming, there are many paradigm terms, one of them is OOP (Object-Oriented Programming).
#
# According to [Dive Into Design Patterns](https://refactoring.guru/design-patterns/book) that is explained by [Indonesia Belajar](https://www.youtube.com/watch?v=_Ld8wMr4OZ4&list=PL2O3HdJI4voFoyU6YyuLBdrsBSZWWtbQt), Object-Oriented Programming is a paradigm based on the concept of wrapping pieces of **data**, and **behaviour** related to that data, into special bundles called [objects](https://docs.python.org/3/glossary.html#term-object), which are constructed from a set of "blueprints", defined by a programmer, called [classes](https://docs.python.org/3/glossary.html#term-class).
#
# Often we will hear the word **object** and **instance** interchangeably, but in general, an object is an instance that has state (attributes or value) and defined behaviour (methods), whereas instance is a spesific object that is created from a class.

# %%
# Creating a class (template) without instance method and special method
class Hero:
    pass

# %%
# Creating an instance of the class Hero
hero1 = Hero()
hero2 =  Hero()

hero1.name = "Gerry"
hero1.health = 100

hero2.name = "Gerry"
hero2.health = 100

# %%
# Print the objects/instances attribute using .__dict__
print(hero1.__dict__)
print(hero2.__dict__)
# Out:
# {'name': 'Gerry', 'health': 100}
# {'name': 'Gerry', 'health': 100}

# %%
# Creating a class (template) with special method __init__ and __repr__
class Vehicle:

    def __init__(self, name: str, color: str) -> None:
        self.name = name
        self.color = color

    def __repr__(self) -> str:
        attrs = ", ".join(f"{key}='{value}'" if isinstance(value, str) else 
                          f"{key}={value}" for key, value in vars(self).items())
        return f"{type(self).__name__}({attrs})"

# %%
# Creating an instance of the class Vehicle
ferrari = Vehicle("La Ferrari", "Red")
lamborghini = Vehicle("Lamborghini Reventon", "Dark")

# %%
print(ferrari)
print(lamborghini)
# Out:
# Vehicle(name='La Ferrari', color='Red')
# Vehicle(name='Lamborghini Reventon', color='Dark')
